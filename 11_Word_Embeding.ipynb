# %% [markdown]
# ###     Word Embedding
# In natural lanuages processing(nlp), word embedding is tem used for representation for next analysis, typically in the formof real-valued vector that encode the meaning of word such that the word are closer in the vector space are expected to be similar in meaning

# %% [markdown]
# Word Embedding ->>> 1. count or frequency   ----> 1. OHE
#                                                   2. BOW
#                                                    3. TF-IDF
#
#                     2. Deep learning Tream
