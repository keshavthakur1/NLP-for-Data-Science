# %% [markdown]
# ### Word2vec
# Word2vec is a technique for natural language processing published in 2013. The word2vector algorithm uses a neural network model a learn word associations from a large corpus to text . ONce trained , such a model can detect synonymous words or suggest additional words for a partial sentence. as the name , words2vec represent each distinct word with  particular list of number called a vector
