# %% [markdown]
# ### TF-IDF [TERM FREQUENCY - INVERSE DOCUMNET FREQUENCY]

# %%
Term freq(TF) :- NO. OF rep of words in sentence/no. of words in sentence

# %%
IDF = loge(no. of sentence/ no. of sentence contain words)
